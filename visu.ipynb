# %%
import matplotlib.pyplot as plt

# Metrics per epoch
epochs = list(range(1, 31))
loss = [0.2121, 0.0763, 0.0369, 0.0213, 0.0136, 0.0090, 0.0074, 0.0054, 0.0040, 0.0043,
        0.0029, 0.0029, 0.0021, 0.0028, 0.0029, 0.0021, 0.0014, 0.0013, 0.0012, 0.0028,
        0.0017, 0.0012, 0.0011, 0.0024, 0.0016, 0.0011, 0.0010, 0.0009, 0.0009, 0.0027]
iou = [0.6113, 0.7960, 0.8591, 0.8877, 0.9074, 0.9243, 0.9257, 0.9360, 0.9462, 0.9384,
       0.9531, 0.9518, 0.9593, 0.9508, 0.9480, 0.9577, 0.9677, 0.9698, 0.9716, 0.9521,
       0.9622, 0.9713, 0.9730, 0.9572, 0.9643, 0.9732, 0.9751, 0.9763, 0.9765, 0.9564]
dice = [0.6772, 0.8468, 0.8990, 0.9219, 0.9362, 0.9495, 0.9508, 0.9580, 0.9660, 0.9597,
        0.9709, 0.9697, 0.9755, 0.9695, 0.9660, 0.9739, 0.9811, 0.9827, 0.9840, 0.9697,
        0.9769, 0.9836, 0.9848, 0.9732, 0.9785, 0.9847, 0.9861, 0.9869, 0.9870, 0.9720]

# Plotting
plt.figure(figsize=(10, 6))
#plt.plot(epochs, loss, label='Loss', color='red', linewidth=2)
plt.plot(epochs, iou, label='IoU', color='green', linewidth=2)
plt.plot(epochs, dice, label='Dice', color='blue', linewidth=2)

# Plot styling
plt.title("Training Metrics Over Epochs", fontsize=16)
plt.xlabel("Epoch", fontsize=12)
plt.ylabel("Value", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# PSNR and SSIM values from each epoch
psnr_list = [
    31.28, 32.99, 24.46, 31.22, 30.10, 26.10, 33.11, 32.52, 32.85, 33.49,
    28.85, 29.30, 36.47, 28.73, 27.79, 28.85, 35.48, 37.38, 36.72, 35.32,
    36.76, 32.70, 37.56, 35.68, 29.61, 38.05, 28.98, 28.80, 38.32, 24.90,
    35.16, 37.17, 35.70, 31.04, 38.72, 37.89, 35.56, 37.92, 35.77, 35.16,
    37.21, 30.12, 30.24, 30.10, 37.04, 37.98, 29.18, 38.12, 38.02
]

ssim_list = [
    0.9679, 0.9647, 0.7535, 0.9621, 0.9619, 0.7863, 0.9568, 0.9678, 0.9716, 0.9700,
    0.8147, 0.8316, 0.9793, 0.8549, 0.7622, 0.7688, 0.9763, 0.9843, 0.9802, 0.9729,
    0.9783, 0.9721, 0.9828, 0.9725, 0.8109, 0.9855, 0.7935, 0.7929, 0.9849, 0.6487,
    0.9744, 0.9839, 0.9785, 0.8634, 0.9842, 0.9817, 0.9714, 0.9832, 0.9742, 0.9748,
    0.9843, 0.7697, 0.8406, 0.7942, 0.9812, 0.9820, 0.7805, 0.9815, 0.9823
]


epochs = list(range(1, len(psnr_values)+1))

# Plot 1: PSNR over Epochs
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, psnr_values, marker='o', color='blue')
plt.title("PSNR over Epochs")
plt.xlabel("Epoch")
plt.ylabel("PSNR")
plt.grid(True)

# Plot 2: SSIM over Epochs
plt.subplot(1, 2, 2)
plt.plot(epochs, ssim_values, marker='o', color='green')
plt.title("SSIM over Epochs")
plt.xlabel("Epoch")
plt.ylabel("SSIM")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Example generator and discriminator loss values for 50 epochs
gen_loss = [2.3946, 2.4807, 2.3323, 2.2962, 2.2380, 2.2542, 2.1801, 2.2385, 2.2542, 2.2593,
2.1422, 2.2417, 2.2048, 2.2417, 2.2048, 2.2048, 2.1934, 2.2515, 2.1825, 2.2162,
2.1473, 2.2788, 2.2854, 2.3235, 2.2479, 2.2736, 2.2839, 2.2970, 2.3010, 2.2863,
2.3120, 2.3145, 2.3042, 2.3233, 2.3262, 2.3195, 2.3375, 2.3401, 2.3185, 2.3189,
2.3201, 2.3426, 2.3570, 2.3511, 2.3550, 2.3450, 2.3642, 2.3597, 2.3689, 2.3682]

disc_loss = [1.4192, 1.4180, 1.3865, 1.3781, 1.3576, 1.3649, 1.3327, 1.3531, 1.3649, 1.3670,
1.3163, 1.3521, 1.3350, 1.3521, 1.3350, 1.3350, 1.3297, 1.3606, 1.3338, 1.3422,
1.3208, 1.3702, 1.3732, 1.3903, 1.3502, 1.3628, 1.3693, 1.3770, 1.3794, 1.3738,
1.3885, 1.3897, 1.3843, 1.3902, 1.3919, 1.3882, 1.3966, 1.3979, 1.3840, 1.3843,
1.3851, 1.3975, 1.4049, 1.4018, 1.4038, 1.3993, 1.4089, 1.4064, 1.4117, 1.4113]

epochs = list(range(1, len(gen_loss) + 1))

# Combined loss plot
plt.figure(figsize=(10, 5))
plt.plot(epochs, gen_loss, label='Generator Loss', color='orange', marker='o')
plt.plot(epochs, disc_loss, label='Discriminator Loss', color='purple', marker='s')
plt.title("Generator vs Discriminator Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
